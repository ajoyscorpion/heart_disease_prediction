# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("/Users/ajoy/dataScience/Practice/cancer detection/framingham.csv")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data.drop(['education'],inplace=True,axis=1)

# %%
data
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
data.rename(columns={'male':"sex_male"},inplace=True)

# %%
data
# Out:
#       sex_male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0            1   39              0         0.0     0.0                0
# 1            0   46              0         0.0     0.0                0
# 2            1   48              1        20.0     0.0                0
# 3            0   61              1        30.0     0.0                0
# 4            0   46              1        23.0     0.0                0
# ...        ...  ...            ...         ...     ...              ...
# 4235         0   48              1        20.0     NaN                0
# 4236         0   44              1        15.0     0.0                0
# 4237         0   52              0         0.0     0.0                0
# 4238         1   40              0         0.0     0.0                0
# 4239         0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
data.dropna(axis=0,inplace=True)

# %%
data
# Out:
#       sex_male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0            1   39              0         0.0     0.0                0
# 1            0   46              0         0.0     0.0                0
# 2            1   48              1        20.0     0.0                0
# 3            0   61              1        30.0     0.0                0
# 4            0   46              1        23.0     0.0                0
# ...        ...  ...            ...         ...     ...              ...
# 4233         1   50              1         1.0     0.0                0
# 4234         1   51              1        43.0     0.0                0
# 4237         0   52              0         0.0     0.0                0
# 4238         1   40              0         0.0     0.0                0
# 4239         0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
# Splitting the Dataset into Test and Train Sets

# %%
x = np.asarray(data[['age','sex_male','cigsPerDay','totChol','sysBP','glucose']])

# %%
y = np.asarray(data[['TenYearCHD']])

# %%
x
# Out:
# array([[ 39. ,   1. ,   0. , 195. , 106. ,  77. ],
#        [ 46. ,   0. ,   0. , 250. , 121. ,  76. ],
#        [ 48. ,   1. ,  20. , 245. , 127.5,  70. ],
#        ...,
#        [ 52. ,   0. ,   0. , 269. , 133.5, 107. ],
#        [ 40. ,   1. ,   0. , 185. , 141. ,  72. ],
#        [ 39. ,   0. ,  30. , 196. , 133. ,  80. ]])

# %%
plt.plot(x)
plt.show()

# %%
y
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
from sklearn import preprocessing

# %%
x = preprocessing.StandardScaler().fit(x).transform(x)

# %%
plt.plot(x)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.8,random_state=24)

# %%
x_train
# Out:
# array([[-0.30031841, -0.89582297,  0.08315246, -1.02964586, -0.33426666,
#          0.13065713],
#        [-0.76711396,  1.11629198,  2.59919077,  0.06886977, -1.46838353,
#         -0.70689714],
#        [-1.58400618, -0.89582297, -0.33618726, -0.33466658,  0.66375619,
#         -0.45563086],
#        ...,
#        [ 0.04977825,  1.11629198, -0.75552698, -1.56769433,  1.20813228,
#          0.21441255],
#        [ 0.74997158, -0.89582297, -0.75552698,  1.63817782,  0.43693281,
#         -0.70689714],
#        [ 0.74997158,  1.11629198, -0.75552698,  0.33789401, -1.15083081,
#         -0.41375315]])

# %%
x_test
# Out:
# array([[ 0.86667046, -0.89582297, -0.75552698,  1.81752731,  1.29886163,
#          1.26135539],
#        [ 0.16647714, -0.89582297, -0.75552698,  0.44998744, -0.19817264,
#          0.25629027],
#        [-0.18361952, -0.89582297, -0.75552698,  0.06886977, -0.60645471,
#         -0.12060915],
#        ...,
#        [ 1.21676713, -0.89582297, -0.75552698,  1.30189752,  1.34422631,
#         -0.45563086],
#        [-0.88381285, -0.89582297, -0.75552698, -1.20899535, -0.56109004,
#         -0.41375315],
#        [ 1.33346602, -0.89582297, -0.75552698, -1.20899535,  0.79985021,
#         -0.49750858]])

# %%
y_test
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
# Exploratory Data Analysis of Heart Disease Dataset

# %%
sns.countplot(x='TenYearCHD' , data=data)
plt.show()

# %%
counts = data['TenYearCHD'].plot()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# /Users/ajoy/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = logreg.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Accuracy

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy Score : ", accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score :  0.850049983338887

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cf_matrix = confusion_matrix(y_test,y_pred)

# %%
cf_matrix
# Out:
# array([[2509,   31],
#        [ 419,   42]])

# %%
sns.heatmap(cf_matrix, annot = True, fmt = 'd', cmap = "Greens")
plt.show()
print("Details of confusion matirx : ",classification_report(y_test,y_pred))
# Out:
# Details of confusion matirx :                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      2540
#            1       0.58      0.09      0.16       461
#
#     accuracy                           0.85      3001
#    macro avg       0.72      0.54      0.54      3001
# weighted avg       0.81      0.85      0.80      3001

# %%
import joblib

# %%
joblib.dump(logreg,"heartDiseasePrediction")
# Out:
# ['heartDiseasePrediction']
